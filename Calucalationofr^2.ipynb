# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(21.0,11.0)

#Reading data 
data = {
    'Head Size(cm^3)':[1,2,3,4,5],
    'Brain weight(grams)':[100,200,300,400,500]
}
df=pd.DataFrame(data)

#Collecting X and Y
X=df['Head Size(cm^3)'].values
Y=df['Brain weight(grams)'].values

# %%
#Mean of X and Y
mean_x=np.mean(X)
mean_y=np.mean(Y)

#Total number of values
n=len(X)

#USing formula to calculate b1 and b2
num=0
denum=0
for i in range(n):
    num += (X[i]-mean_x)*(Y[i]-mean_y)
    denum += (X[i]-mean_x)**2
    print(num, denum)
    print(num/denum, mean_y-(Y[i]*mean_x))
b1=num/denum
b2=mean_y-(b1*mean_x)

#print the coefficient 
print(b1, b2)
# Out:
# 400.0 4.0
# 100.0 0.0
# 500.0 5.0
# 100.0 -300.0
# 500.0 5.0
# 100.0 -600.0
# 600.0 6.0
# 100.0 -900.0
# 1000.0 10.0
# 100.0 -1200.0
# 100.0 0.0

# %%
import matplotlib.pyplot as plt 

#Assuming the previous code for calculating B0, b1, and defining X, Y, already executed

max_x=np.max(X)+100
min_x=np.min(X)-100
#Calculating line values of x and y
x=np.linspace(min_x, max_x, 1000)
y=b2 + b1*x

#Plotting line 
plt.plot(x,y,color='#58b970', label='Regression line')
#Plotting Scatter Point
plt.scatter(X,Y, c='#ef5423',label='Scatter Plot')

plt.xlabel('Head Size in cm3')
plt.ylabel('Brainsize Weght in grams')
plt.legend()
plt.show()

# %%
ss_t=0
ss_r=0
for i in range(n):
    y_pred=b2+b1*X[i]
    ss_t+=(Y[i]-mean_y)**2
    ss_r+=(Y[i]-y_pred)**2

r2=1-(ss_r/ss_t)
print(r2)
# Out:
# 1.0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
#Reshaping X
X=X.reshape((n,1))

#Creating model
reg=LinearRegression()

#Filtering training data
reg=reg.fit(X,Y)

#Y Prediction
Y_pred=reg.predict(X)

#Calculating R2 score 
r2_score=r2_score(X,Y)
print(r2_score)
# Out:
# -53904.5
